# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
transitions = pd.read_csv('ramp_fit_results_AMOC_SFWF_PD.csv')
X = pd.read_csv('CombinedDatasetLongUnsmooth.csv')
AMOC = X['AMOC_40N']
transitions
# Out:
#     Variable    Label     t0     t1         a0         a1     Height  \
# 0   AMOC_40N     1 Up   1126   1247   7.253962  23.723510  16.469548
# 1       SFWF     1 Up   1096   1266  -0.000017   0.000040   0.000057
# 2    PD_200m     1 Up   1120   1258   1.028456   1.028805   0.000349
# 3   AMOC_40N   1 Down   1505   1704  17.887867   5.492967 -12.394899
# 4       SFWF   1 Down   1479   1678   0.000022  -0.000014  -0.000036
# ..       ...      ...    ...    ...        ...        ...        ...
# 70      SFWF  12 Down  29745  29944   0.000027  -0.000012  -0.000040
# 71   PD_200m  12 Down  29780  29979   1.028677   1.028226  -0.000451
# 72  AMOC_40N    13 Up  30504  30648   7.003903  23.546979  16.543076
# 73      SFWF    13 Up  30480  30674  -0.000016   0.000047   0.000062
# 74   PD_200m    13 Up  30513  30661   1.028223   1.028762   0.000540
#
#    Direction  Zoom_Start  Zoom_End
# 0         up        1000      1400
# 1         up        1000      1400
# ...

# %%
plt.figure(figsize=(14,6))

plt.plot(AMOC[1400:1800])
plt.legend()
# Out:
# /var/folders/vx/_qz127vd3pz36ngtp3sys4fw0000gn/T/ipykernel_99413/217081478.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.figure(figsize=(14,6))

plt.plot(AMOC[1505:1704])
plt.legend()
# Out:
# /var/folders/vx/_qz127vd3pz36ngtp3sys4fw0000gn/T/ipykernel_99413/4258418178.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
