# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
X_full = pd.read_csv('../data/CombinedDatasetLongUnsmooth.csv')
X = pd.read_csv('../data/CESMDataset_Try.csv')

# %%
X_full
# Out:
#             AMOC   AMOC_20S  MOC_30SAABW         NAO      SFWF        N_SALT  \
# 0       5.483075   5.023636   -10.239799 -120.437500 -0.000012 -9.507178e+09
# 1       4.629497   5.414859   -11.201758 -146.156250 -0.000011 -8.816568e+09
# 2       5.921694   4.797603   -12.287320    0.796875 -0.000010 -9.958823e+09
# 3       6.002988   5.721677    -8.847480  -18.187500 -0.000010 -6.875848e+09
# 4       7.661625   6.777617   -10.571012  -46.929688 -0.000012 -8.184854e+09
# ...          ...        ...          ...         ...       ...           ...
# 31587  12.112252  11.716640    -7.854745 -154.820312  0.000021 -1.025373e+10
# 31588  11.741478  11.940147    -6.544353  -22.609375  0.000023 -9.361673e+09
# 31589  11.639159  11.863952    -7.244836  373.250000  0.000018 -8.494928e+09
# 31590  11.692462  10.989410    -6.791933   57.867188  0.000019 -7.159760e+09
# 31591  11.288474  11.416160    -8.479085 -478.820312  0.000025 -8.546611e+09
#
# ...

# %%
AMOC_full = X_full['AMOC_40N']
AMOC = X['AMOC']

# %%
plt.figure(figsize=(14,6))

plt.plot(AMOC)

# %%
plt.figure(figsize=(14,6))

plt.plot(AMOC_full[12500:18500])

# %%
plt.figure(figsize=(14,6))

plt.plot(AMOC_full[16300:16800])

# %%
[12900, 13600, 15250, 15650, 16350, 17900]

# %%
plt.hist(AMOC_full[:16000], bins = 100);
